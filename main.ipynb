# %%
import pandas as pd
import numpy as np

# %%
df_pop_germany = pd.read_excel("Destatis_Q42022_Alter_Geschlecht_Familienstand__Ausländer_Mengen__melted_v1.xlsx")

# %%
df_pop_germany
# Out:
#              Jahr Nationalität Geschlecht                  Familienstatus  \
# 0      31.12.2014     Deutsche   männlich                           ledig
# 1      31.12.2014     Deutsche   männlich                     verheiratet
# 2      31.12.2014     Deutsche   männlich                       verwitwet
# 3      31.12.2014     Deutsche   männlich                      geschieden
# 4      31.12.2014     Deutsche   männlich             Lebenspartnerschaft
# ...           ...          ...        ...                             ...
# 21752  31.12.2022    Ausländer   weiblich                       verwitwet
# 21753  31.12.2022    Ausländer   weiblich                      geschieden
# 21754  31.12.2022    Ausländer   weiblich             Lebenspartnerschaft
# 21755  31.12.2022    Ausländer   weiblich  Lebenspartnerschaft aufgehoben
# 21756  31.12.2022    Ausländer   weiblich        Lebenspartner verstorben
#
#        Alter  Anzahl
# 0          0  339249
# 1          0       -
# ...

# %%
df_pop_germany[df_pop_germany["Jahr"] > "31.12.2015"]
# Out:
#              Jahr Nationalität Geschlecht                  Familienstatus  \
# 56     31.12.2016     Deutsche   männlich                           ledig
# 57     31.12.2016     Deutsche   männlich                     verheiratet
# 58     31.12.2016     Deutsche   männlich                       verwitwet
# 59     31.12.2016     Deutsche   männlich                      geschieden
# 60     31.12.2016     Deutsche   männlich             Lebenspartnerschaft
# ...           ...          ...        ...                             ...
# 21752  31.12.2022    Ausländer   weiblich                       verwitwet
# 21753  31.12.2022    Ausländer   weiblich                      geschieden
# 21754  31.12.2022    Ausländer   weiblich             Lebenspartnerschaft
# 21755  31.12.2022    Ausländer   weiblich  Lebenspartnerschaft aufgehoben
# 21756  31.12.2022    Ausländer   weiblich        Lebenspartner verstorben
#
#        Alter  Anzahl
# 56         0  353889
# 57         0       -
# ...

# %%
# Out:
#              Jahr Nationalität Geschlecht                  Familienstatus  \
# 0      31.12.2014     Deutsche   männlich                           ledig
# 1      31.12.2014     Deutsche   männlich                     verheiratet
# 2      31.12.2014     Deutsche   männlich                       verwitwet
# 3      31.12.2014     Deutsche   männlich                      geschieden
# 4      31.12.2014     Deutsche   männlich             Lebenspartnerschaft
# ...           ...          ...        ...                             ...
# 21753  31.12.2022    Ausländer   weiblich                      geschieden
# 21754  31.12.2022    Ausländer   weiblich             Lebenspartnerschaft
# 21755  31.12.2022    Ausländer   weiblich  Lebenspartnerschaft aufgehoben
# 21756  31.12.2022    Ausländer   weiblich        Lebenspartner verstorben
# 21757  __________          NaN        NaN                             NaN
#
#       Alter  Anzahl
# 0         0  339249
# 1         0       -
# ...
